# %%
from aprec.datasets.movielens import get_movielens_actions
from collections import Counter
from matplotlib import pyplot as plt
import seaborn
import 
# %matplotlib notebook
seaborn.set()

# %%
actions = []
for action in get_movielens_actions():
    actions.append(action)

# %%
users = Counter()

# %%
for action in actions:
    users[action.user_id] += 1

# %%
np.pe
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1.6100e+03, 3.3300e+03, 5.8440e+03, 8.1860e+03, 9.0720e+03,
#         1.1025e+04, 6.9460e+03, 6.2720e+03, 5.3300e+03, 4.7110e+03,
#         4.3620e+03, 5.0430e+03, 3.5020e+03, 3.1830e+03, 2.9530e+03,
#         2.6440e+03, 2.4950e+03, 3.0300e+03, 2.0310e+03, 1.8950e+03,
#         1.8080e+03, 1.6950e+03, 2.1740e+03, 1.5080e+03, 1.4600e+03,
#         1.4100e+03, 1.3220e+03, 1.1730e+03, 1.5060e+03, 1.0720e+03,
#         1.0490e+03, 9.9400e+02, 9.2700e+02, 8.6700e+02, 1.1200e+03,
#         7.8100e+02, 7.6900e+02, 7.6500e+02, 7.0300e+02, 9.2000e+02,
#         6.6900e+02, 5.8000e+02, 5.2900e+02, 5.9300e+02, 5.5300e+02,
#         7.0500e+02, 4.9600e+02, 4.7400e+02, 4.6600e+02, 4.5400e+02,
#         4.7800e+02, 5.5900e+02, 3.6100e+02, 3.8800e+02, 3.6600e+02,
#         3.8600e+02, 4.7200e+02, 3.3200e+02, 3.1200e+02, 3.0400e+02,
#         3.1600e+02, 2.8800e+02, 3.6400e+02, 2.3800e+02, 2.6200e+02,
# ...
